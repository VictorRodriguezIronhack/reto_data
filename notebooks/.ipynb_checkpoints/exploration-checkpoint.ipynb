# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append("..")

# %%
df = pd.read_csv('../data/clean_data.csv')

# %%
df
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type  AC  rain  \
# 0        28.0      5.0     26         21.5            12      E10   0     0
# 1        12.0      4.2     30         21.5            13      E10   0     0
# 2        11.2      5.5     38         21.5            15      E10   0     0
# 3        12.9      3.9     36         21.5            14      E10   0     0
# 4        18.5      4.5     46         21.5            15      E10   0     0
# ..        ...      ...    ...          ...           ...      ...  ..   ...
# 371      16.0      3.7     39         24.5            18     SP98   0     0
# 372      16.1      4.3     38         25.0            31     SP98   1     0
# 373      16.0      3.8     45         25.0            19     SP98   0     0
# 374      15.4      4.6     42         25.0            31     SP98   1     0
# 375      14.7      5.0     25         25.0            30     SP98   1     0
#
#      sun
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ..   ...
# 371    0
# 372    0
# 373    0
# 374    0
# 375    0
#
# [376 rows x 9 columns]

# %%
sns.pairplot(df, hue="gas_type")

# %%
sns.boxplot(df.distance)
# Out:
# /home/sergio/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.corr()
# Out:
#               distance   consume     speed  temp_inside  temp_outside  \
# distance      1.000000 -0.131379  0.565505     0.075305      0.086774
# consume      -0.131379  1.000000 -0.234537    -0.161991     -0.318758
# speed         0.565505 -0.234537  1.000000     0.059725      0.019327
# temp_inside   0.075305 -0.161991  0.059725     1.000000      0.361308
# temp_outside  0.086774 -0.318758  0.019327     0.361308      1.000000
# AC           -0.027670  0.093892 -0.036351     0.297775      0.169374
# rain         -0.022129  0.247699 -0.002936    -0.037356     -0.185731
# sun           0.078627 -0.169173  0.077181     0.246120      0.349988
#
#                     AC      rain       sun
# distance     -0.027670 -0.022129  0.078627
# consume       0.093892  0.247699 -0.169173
# speed        -0.036351 -0.002936  0.077181
# temp_inside   0.297775 -0.037356  0.246120
# temp_outside  0.169374 -0.185731  0.349988
# AC            1.000000  0.244848  0.090164
# rain          0.244848  1.000000 -0.113298
# sun           0.090164 -0.113298  1.000000

# %%
sns.histplot(x=df.distance)

# %%
df_a = df[df.distance<=50].reset_index(drop=True)

# %%
sns.histplot(x=df_a.distance)

# %% [markdown]
# # Feature engineering

# %%
df_a['gasoline'] = df_a.gas_type.apply(lambda x: 0 if x =='E10' else 1)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df_list = [df_a[df_a.gasoline == 0], df_a[df_a.gasoline == 1]]

# %%
df_gas = df_a.copy()
X = df_gas[['distance','speed','temp_outside','AC','rain','sun','gasoline']]
y = df_gas['consume']
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                y, 
                                                test_size=0.15, 
                                                random_state=46)

# %%
gb = GradientBoostingRegressor()

parameter_space = {'learning_rate': [0.01, 0.001],
                   'n_estimators': [3000,5000, 7000],
               'max_features': [1,0.5],
               'max_depth': [2,3,5],
               'min_samples_leaf': [10,15]}

grid_search = GridSearchCV(gb,
                   param_grid=parameter_space,
                   verbose=1,
                    n_jobs= -1,
                   cv=5)

grid_search.fit(X_train, y_train)

gb_best = grid_search.best_estimator_
y_predict_test = gb_best.predict(X_test) 

score = mean_squared_error(y_test, y_predict_test)

params = (grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   51.4s finished

# %%
score
# Out:
# 0.1582434263233483

# %%
params
# Out:
# {'learning_rate': 0.001,
#  'max_depth': 5,
#  'max_features': 0.5,
#  'min_samples_leaf': 10,
#  'n_estimators': 5000}

# %%
gb_best.fit(X,y)
# Out:
# GradientBoostingRegressor(learning_rate=0.001, max_depth=5, max_features=0.5,
#                           min_samples_leaf=10, n_estimators=5000)

# %% [markdown]
# # Experiment

# %%
import random

# %%
tmp_list = []

for _ in range(10000):
    
    distance = round(random.uniform(1, 50),1)
    speed = round(random.uniform(14, 90),1)
    temp_outside = round(random.uniform(-5, 40),1)
    ac = random.choice([0,1])
    rain = random.choice([0,1])
    sun = random.choice([0,1])
    gasoline = random.choice([0,1])
    
    
    tmp_list.append([distance, speed, temp_outside, ac, rain, sun])

df_exp = pd.DataFrame(tmp_list, columns = X_train.columns[:-1] )

# %%
df_exp.loc[:,:'sun']
# Out:
#       distance  speed  temp_outside  AC  rain  sun
# 0         39.4   67.1           9.9   0     0    0
# 1         14.3   37.9           3.0   1     1    1
# 2         22.8   73.1          25.3   1     0    0
# 3         37.9   79.8          -4.0   1     0    1
# 4         12.6   71.7           1.8   0     1    0
# ...        ...    ...           ...  ..   ...  ...
# 9995      32.3   89.7          27.6   1     1    0
# 9996      20.1   68.1          16.0   0     1    1
# 9997      44.8   31.4          39.0   0     1    1
# 9998      13.8   66.5          10.3   1     1    1
# 9999       6.7   48.1          15.4   0     0    1
#
# [10000 rows x 6 columns]

# %%
X_exp = df_exp.loc[:,:'sun']
X_exp['gasoline'] = 0
df_exp['E10_consum_pred'] = gb_best.predict(X_exp)
X_exp = df_exp.loc[:,:'sun']
X_exp['gasoline'] = 1
df_exp['SP98_consum_pred'] = gb_best.predict(X_exp)

# %%
df_exp
# Out:
#       distance  speed  temp_outside  AC  rain  sun  E10_consum_pred  \
# 0         39.4   67.1           9.9   0     0    0         4.836615
# 1         14.3   37.9           3.0   1     1    1         5.388400
# 2         22.8   73.1          25.3   1     0    0         4.489509
# 3         37.9   79.8          -4.0   1     0    1         4.986231
# 4         12.6   71.7           1.8   0     1    0         5.556442
# ...        ...    ...           ...  ..   ...  ...              ...
# 9995      32.3   89.7          27.6   1     1    0         4.783365
# 9996      20.1   68.1          16.0   0     1    1         4.591074
# 9997      44.8   31.4          39.0   0     1    1         4.506314
# 9998      13.8   66.5          10.3   1     1    1         5.313538
# 9999       6.7   48.1          15.4   0     0    1         4.926443
#
#       SP98_consum_pred
# 0             4.819579
# 1             5.329854
# 2             4.477336
# 3             5.010732
# 4             5.593423
# ...                ...
# 9995          4.785831
# 9996          4.590469
# 9997          4.465992
# 9998          5.329965
# 9999          4.875601
#
# [10000 rows x 8 columns]

# %%
df_exp[['E10_consum_pred', 'SP98_consum_pred']].mean()
# Out:
# E10_consum_pred     5.072304
# SP98_consum_pred    5.062472
# dtype: float64

# %%
fig, ax = plt.subplots()
sns.barplot(x = ['E10','SP98'],y= df_exp[['E10_consum_pred', 'SP98_consum_pred']].mean().values)

plt.ylabel('Consumption L/100km') #To remove countries
# Out:
# Text(0, 0.5, 'Consumption L/100km')

# %%
ratio = 1.00
df_exp['E10_high'] = df_exp.apply(lambda x: 0 if (x.E10_consum_pred / x.SP98_consum_pred)/ratio <1 else 1, axis=1)

# %%
df_exp.E10_high.value_counts()
# Out:
# 1    5654
# 0    4346
# Name: E10_high, dtype: int64

# %%
sns.pairplot(df_exp[['distance', 'speed','temp_outside','E10_high']], hue= 'E10_high', plot_kws={'s':1})

# %%
ratio = 1.05
df_exp['E10_high_price'] = df_exp.apply(lambda x: 0 if (x.E10_consum_pred / x.SP98_consum_pred)/ratio <1 else 1, axis=1)
sns.pairplot(df_exp[['distance', 'speed','temp_outside','E10_high_price']], hue= 'E10_high_price', plot_kws={'s':1})

# %%
df_prices = pd.read_pickle('../data/prices')

# %%
df_95 = df_prices[(df_prices.gas_type == 'Sin plomo 95')].drop('gas_type', axis=1)
df_98 = df_prices[(df_prices.gas_type == 'Sin plomo 98')].drop('gas_type', axis=1)

# %%
df_prices_merge = df_95.merge(df_98, how='inner', on=['name', 'direction']).rename(columns={'price_x': 'price_E10', 'price_y':'price_SP98'})

# %%
df_prices_merge
# Out:
#                                                   name  \
# 0    Gasolinera SHELL en MADRID (MADRID)CALLE SANTO...
# 1    Gasolinera PETROLANDIA en MADRID (MADRID)CR M-...
# 2    Gasolinera GALP en MADRID (MADRID)AVENIDA DE L...
# 3    Gasolinera CEPSA en MADRID (MADRID)AVENIDA DE ...
# 4    Gasolinera REPSOL en MADRID (MADRID)CL ARTURO ...
# ..                                                 ...
# 135  Gasolinera SHELL ATALAYUELA 365 en MADRID (MAD...
# 136  Gasolinera BP SAN PEDRO MD en MADRID (MADRID)C...
# 137  Gasolinera SHELL en MADRID (MADRID)CALLE CARDE...
# 138  Gasolinera Q8 en MADRID (MADRID)AVENIDA ALBUFE...
# 139  Gasolinera BP E.S. NAVALCARRO en MADRID (MADRI...
#
#                               direction price_E10 price_SP98
# 0               CALLE SANTO DOMINGO, 10     1,339      1,479
# 1                        CR M-607, 11,7     1,256      1,400
# 2           AVENIDA DE LOS POBLADOS, SN     1,319      1,444
# 3           AVENIDA DE LOS POBLADOS, 18     1,329      1,444
# 4                  CL ARTURO SORIA, 175     1,339      1,489
# ..                                  ...       ...        ...
# 135               CALLE GUADALCANAL, 36     1,169      1,349
# 136  CR A-3  MG IZDO, KM 11,2 km 11,200     1,279      1,421
# 137     CALLE CARDENAL HERRERA ORIA, 81     1,339      1,479
# 138                AVENIDA ALBUFERA, 89     1,315      1,425
# 139                       M-607 km 17.7     1,299      1,419
#
# [140 rows x 4 columns]

# %%
df_prices_merge['price_E10'] = df_prices_merge['price_E10'].str.replace(',', '').astype(float)
df_prices_merge['price_SP98'] = df_prices_merge['price_SP98'].str.replace(',', '').astype(float)

# %%
df_prices_merge['ratio98_95'] = df_prices_merge.price_SP98.astype(float) / df_prices_merge.price_E10.astype(float)

# %%
df_prices_merge.ratio98_95.describe()
# Out:
# count    140.000000
# mean       1.103848
# std        0.015831
# min        1.053888
# 25%        1.094717
# 50%        1.106847
# 75%        1.112024
# max        1.153978
# Name: ratio98_95, dtype: float64
