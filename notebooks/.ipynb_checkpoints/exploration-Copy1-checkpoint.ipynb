# %%
import seaborn as sns
import pandas as pd
import sys
sys.path.append("..")

# %%
df = pd.read_csv('../data/clean_data.csv')

# %%
df
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type  AC  rain  \
# 0        28.0      5.0     26         21.5            12      E10   0     0
# 1        12.0      4.2     30         21.5            13      E10   0     0
# 2        11.2      5.5     38         21.5            15      E10   0     0
# 3        12.9      3.9     36         21.5            14      E10   0     0
# 4        18.5      4.5     46         21.5            15      E10   0     0
# ..        ...      ...    ...          ...           ...      ...  ..   ...
# 371      16.0      3.7     39         24.5            18     SP98   0     0
# 372      16.1      4.3     38         25.0            31     SP98   1     0
# 373      16.0      3.8     45         25.0            19     SP98   0     0
# 374      15.4      4.6     42         25.0            31     SP98   1     0
# 375      14.7      5.0     25         25.0            30     SP98   1     0
#
#      sun
# 0      0
# 1      0
# 2      0
# 3      0
# ...

# %%
sns.pairplot(df, hue="gas_type")

# %%
sns.boxplot(df.distance)
# Out:
# /home/sergio/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.corr()
# Out:
#               distance   consume     speed  temp_inside  temp_outside  \
# distance      1.000000 -0.131379  0.565505     0.075305      0.086774
# consume      -0.131379  1.000000 -0.234537    -0.161991     -0.318758
# speed         0.565505 -0.234537  1.000000     0.059725      0.019327
# temp_inside   0.075305 -0.161991  0.059725     1.000000      0.361308
# temp_outside  0.086774 -0.318758  0.019327     0.361308      1.000000
# AC           -0.027670  0.093892 -0.036351     0.297775      0.169374
# rain         -0.022129  0.247699 -0.002936    -0.037356     -0.185731
# sun           0.078627 -0.169173  0.077181     0.246120      0.349988
#
#                     AC      rain       sun
# distance     -0.027670 -0.022129  0.078627
# consume       0.093892  0.247699 -0.169173
# speed        -0.036351 -0.002936  0.077181
# temp_inside   0.297775 -0.037356  0.246120
# temp_outside  0.169374 -0.185731  0.349988
# AC            1.000000  0.244848  0.090164
# ...

# %%
df_a = df[df.distance<=50].reset_index(drop=True)

# %% [markdown]
# # Feature engineering

# %%
df_a['gasoline'] = df_a.gas_type.apply(lambda x: 0 if x =='E10' else 1)

# %% [markdown]
# ## Type of drives

# %%
X =  df_a[['distance','speed']]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
import matplotlib.pyplot as plt

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
X_scaled = scaler.transform(X)

# %%
from yellowbrick.cluster import KElbowVisualizer

# %%
model = KMeans()
visualizer = KElbowVisualizer(
    model, k=(2,8), metric='calinski_harabasz', timings=False
)

visualizer.fit(X_scaled)        # Fit the data to the visualizer
visualizer.show()

# %%
k_means = KMeans(n_clusters=5, 
                 random_state=0)

k_means.fit(X_scaled)

data = pd.DataFrame(X_scaled, columns=['distance', 'speed'])
data['cluster'] = k_means.labels_

sns.scatterplot(x = data.distance, y = data.speed, data=data, s= 100, hue=data.cluster)
plt.xlabel('distance', size=20)
plt.ylabel('speed', size=20)
# plt.scatter(data.PC1, data.PC2)
plt.show()

# %%
data
# Out:
#      distance     speed  cluster
# 0    1.427563 -1.230512        4
# 1   -0.475767 -0.890963        1
# 2   -0.570933 -0.211865        0
# 3   -0.368704 -0.381640        0
# 4    0.297461  0.467232        0
# ..        ...       ...      ...
# 356  0.000066 -0.126978        0
# 357  0.011962 -0.211865        0
# 358  0.000066  0.382345        0
# 359 -0.071309  0.127684        0
# 360 -0.154580 -1.315399        1
#
# [361 rows x 3 columns]

# %%
df_a
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type  AC  rain  \
# 0        28.0      5.0     26         21.5            12      E10   0     0
# 1        12.0      4.2     30         21.5            13      E10   0     0
# 2        11.2      5.5     38         21.5            15      E10   0     0
# 3        12.9      3.9     36         21.5            14      E10   0     0
# 4        18.5      4.5     46         21.5            15      E10   0     0
# ..        ...      ...    ...          ...           ...      ...  ..   ...
# 371      16.0      3.7     39         24.5            18     SP98   0     0
# 372      16.1      4.3     38         25.0            31     SP98   1     0
# 373      16.0      3.8     45         25.0            19     SP98   0     0
# 374      15.4      4.6     42         25.0            31     SP98   1     0
# 375      14.7      5.0     25         25.0            30     SP98   1     0
#
#      sun  gasoline  type_drive
# ...

# %%
df_a['type_drive'] = data['cluster'].copy()

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df_list = [df_a[df_a.gasoline == 0], df_a[df_a.gasoline == 1]]

# %%
df_gas = df_list[0]
X = df_gas[['temp_outside','AC','rain','sun','type_drive']]
y = df_gas['consume']
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                y, 
                                                test_size=0.1, 
                                                random_state=46)

# %%
gb = GradientBoostingRegressor()

parameter_space = {'learning_rate': [0.01, 0.001],
                   'n_estimators': [2000,3000],
               'max_features': [1],
               'max_depth': [2,3],
               'min_samples_leaf': [7, 10,15]}

grid_search = GridSearchCV(gb,
                   param_grid=parameter_space,
                   verbose=1,
                    n_jobs= -1,
                   cv=5)

grid_search.fit(X_train, y_train)

gb_best = grid_search.best_estimator_
y_predict_test = gb_best.predict(X_test) 

score = mean_squared_error(y_test, y_predict_test)

params = (grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.8s finished

# %%
score
# Out:
# 0.34127491592418013

# %%
params
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 2,
#  'max_features': 1,
#  'min_samples_leaf': 10,
#  'n_estimators': 2000}

# %%
gb_best.fit(X,y)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=2, max_features=1,
#                           min_samples_leaf=10, n_estimators=2000)

# %%
list_predictors = []

# %%
list_predictors.append(gb_best)

# %%
df_gas = df_list[1]
X = df_gas[['temp_outside','AC','rain','sun','type_drive']]
y = df_gas['consume']
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                y, 
                                                test_size=0.1, 
                                                random_state=46)

# %%
gb = GradientBoostingRegressor()

parameter_space = {'learning_rate': [0.01, 0.001],
                   'n_estimators': [2000,3000],
               'max_features': [1],
               'max_depth': [2,3],
               'min_samples_leaf': [7, 10,15]}

grid_search = GridSearchCV(gb,
                   param_grid=parameter_space,
                   verbose=1,
                    n_jobs= -1,
                   cv=5)

grid_search.fit(X_train, y_train)

gb_best = grid_search.best_estimator_
y_predict_test = gb_best.predict(X_test) 

score = mean_squared_error(y_test, y_predict_test)

params = (grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.4s finished

# %%
score
# Out:
# 0.2790458466778929

# %%
params
# Out:
# {'learning_rate': 0.001,
#  'max_depth': 3,
#  'max_features': 1,
#  'min_samples_leaf': 10,
#  'n_estimators': 3000}

# %%
gb_best.fit(X,y)
# Out:
# GradientBoostingRegressor(learning_rate=0.001, max_features=1,
#                           min_samples_leaf=10, n_estimators=3000)

# %%
list_predictors.append(gb_best)

# %%
list_predictors
# Out:
# [GradientBoostingRegressor(learning_rate=0.01, max_depth=2, max_features=1,
#                            min_samples_leaf=10, n_estimators=2000),
#  GradientBoostingRegressor(learning_rate=0.001, max_features=1,
#                            min_samples_leaf=10, n_estimators=3000)]

# %%
sns.scatterplot(x=df.type_drive, y = df.consume, hue=df.gasoline)

# %%
X_test
# Out:
#      temp_outside  AC  rain  sun  type_drive
# 257             8   0     0    0           0
# 48             11   0     0    0           1
# 357            31   1     0    0           0
# 176             9   0     1    0           3
# 194             9   0     0    0           0
# 329            16   0     0    0           2
# 339            30   1     0    1           2
# 119             1   0     0    0           0
# 61              6   0     0    0           1
# 294            14   0     0    0           3
# 262            12   0     0    0           3
# 87             11   0     0    0           0
# 261            14   0     0    0           4
# 341            21   1     0    0           0
# 106             3   0     0    0           1
# 270            18   0     0    0           0
# 55              7   0     0    0           1
# 335            18   0     0    0           2
# 186            12   1     1    0           1
# 127             5   0     1    0           4
# ...

# %%
list_predictors[0].predict([[5,0,0,0,1],[35,1,0,0,3]])
# Out:
# array([5.74450606, 4.23829301])

# %%
list_predictors[1].predict([[30,0,0,0,1],[35,1,0,0,3]])
# Out:
# array([4.81103335, 4.82120242])
