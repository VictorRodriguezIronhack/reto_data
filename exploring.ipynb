# %% [markdown]
# # Exploring and cleaning

# %%
import pandas as pd
import os

# %%
# Import the dataset we want to analyze
data = pd.read_csv("./data/measurements.csv")
data.head()
# Out:
#   distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0       28       5     26        21,5            12      NaN      E10   0
# 1       12     4,2     30        21,5            13      NaN      E10   0
# 2     11,2     5,5     38        21,5            15      NaN      E10   0
# 3     12,9     3,9     36        21,5            14      NaN      E10   0
# 4     18,5     4,5     46        21,5            15      NaN      E10   0
#
#    rain  sun refill liters refill gas
# 0     0    0            45        E10
# 1     0    0           NaN        NaN
# 2     0    0           NaN        NaN
# 3     0    0           NaN        NaN
# 4     0    0           NaN        NaN

# %%
# What type of data do we have in each column?
data.dtypes
# Out:
# distance         object
# consume          object
# speed             int64
# temp_inside      object
# temp_outside      int64
# specials         object
# gas_type         object
# AC                int64
# rain              int64
# sun               int64
# refill liters    object
# refill gas       object
# dtype: object

# %%
# Transform object to number
def comma_to_float(df,column_name):
    index = df.columns.get_loc(column_name)
    for i in range(len(df[column_name])):
        value = df.iloc[i,index]
        value_list = value.split(',')
        if len(value_list) == 2:
            new_value = float(''.join(value_list)) / 10
            data.iloc[i,index] = new_value
        else:
            data.iloc[i,index] = float(value)

# %%
comma_to_float(data, 'distance')
data['distance'] = data['distance'].astype(float)
comma_to_float(data, 'consume')
data['consume'] = data['consume'].astype(float)
data['speed'] = data['speed'].astype(float)

# %%
#See data
data
# Out:
#      distance  consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0        28.0      5.0   26.0        21,5            12      NaN      E10   0
# 1        12.0      4.2   30.0        21,5            13      NaN      E10   0
# 2        11.2      5.5   38.0        21,5            15      NaN      E10   0
# 3        12.9      3.9   36.0        21,5            14      NaN      E10   0
# 4        18.5      4.5   46.0        21,5            15      NaN      E10   0
# ..        ...      ...    ...         ...           ...      ...      ...  ..
# 383      16.0      3.7   39.0        24,5            18      NaN     SP98   0
# 384      16.1      4.3   38.0          25            31       AC     SP98   1
# 385      16.0      3.8   45.0          25            19      NaN     SP98   0
# 386      15.4      4.6   42.0          25            31       AC     SP98   1
# 387      14.7      5.0   25.0          25            30       AC     SP98   1
#
#      rain  sun refill liters refill gas
# 0       0    0            45        E10
# 1       0    0           NaN        NaN
# 2       0    0           NaN        NaN
# 3       0    0           NaN        NaN
# 4       0    0           NaN        NaN
# ..    ...  ...           ...        ...
# 383     0    0           NaN        NaN
# 384     0    0           NaN        NaN
# 385     0    0           NaN        NaN
# 386     0    0           NaN        NaN
# 387     0    0           NaN        NaN
#
# [388 rows x 12 columns]

# %%
# What type of data do we have in each column?
data.dtypes
# Out:
# distance         float64
# consume          float64
# speed            float64
# temp_inside       object
# temp_outside       int64
# specials          object
# gas_type          object
# AC                 int64
# rain               int64
# sun                int64
# refill liters     object
# refill gas        object
# dtype: object

# %%
# We calculate null ratio for each column. Only two of our columns have more than 10% of null data.
# We have 3 columns with more than 70% null values
perc_null_col = data.isnull().sum().apply(lambda x: x/data.shape[0]).sort_values(ascending=False)
perc_null_col
# Out:
# refill gas       0.966495
# refill liters    0.966495
# specials         0.760309
# temp_inside      0.030928
# sun              0.000000
# rain             0.000000
# AC               0.000000
# gas_type         0.000000
# temp_outside     0.000000
# speed            0.000000
# consume          0.000000
# distance         0.000000
# dtype: float64

# %%
#Look for uniques values per column
data["specials"].value_counts(dropna=False)
# Out:
# NaN                   295
# rain                   32
# sun                    27
# AC rain                 9
# ac                      8
# AC                      6
# snow                    3
# sun ac                  3
# half rain half sun      1
# ac rain                 1
# AC snow                 1
# AC Sun                  1
# AC sun                  1
# Name: specials, dtype: int64

# %%
data["gas_type"].value_counts(dropna=False)
# Out:
# SP98    228
# E10     160
# Name: gas_type, dtype: int64

# %%
data["AC"].value_counts(dropna=False)
# Out:
# 0    358
# 1     30
# Name: AC, dtype: int64

# %%
data["refill gas"].value_counts(dropna=False)
# Out:
# NaN     375
# SP98      8
# E10       5
# Name: refill gas, dtype: int64

# %%
data["specials"].value_counts(dropna=False)
# Out:
# NaN                   295
# rain                   32
# sun                    27
# AC rain                 9
# ac                      8
# AC                      6
# snow                    3
# sun ac                  3
# half rain half sun      1
# ac rain                 1
# AC snow                 1
# AC Sun                  1
# AC sun                  1
# Name: specials, dtype: int64

# %%
# Drop non usefull columns
drop_cols = ["refill gas","refill liters", "specials"]
data = data.drop(drop_cols, axis =1)
data
# Out:
#      distance  consume  speed temp_inside  temp_outside gas_type  AC  rain  \
# 0        28.0      5.0   26.0        21,5            12      E10   0     0
# 1        12.0      4.2   30.0        21,5            13      E10   0     0
# 2        11.2      5.5   38.0        21,5            15      E10   0     0
# 3        12.9      3.9   36.0        21,5            14      E10   0     0
# 4        18.5      4.5   46.0        21,5            15      E10   0     0
# ..        ...      ...    ...         ...           ...      ...  ..   ...
# 383      16.0      3.7   39.0        24,5            18     SP98   0     0
# 384      16.1      4.3   38.0          25            31     SP98   1     0
# 385      16.0      3.8   45.0          25            19     SP98   0     0
# 386      15.4      4.6   42.0          25            31     SP98   1     0
# 387      14.7      5.0   25.0          25            30     SP98   1     0
#
#      sun
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ..   ...
# 383    0
# 384    0
# 385    0
# 386    0
# 387    0
#
# [388 rows x 9 columns]

# %%
# Exporting our cleaned dataset
data.to_csv("output/data.csv", index = False)
