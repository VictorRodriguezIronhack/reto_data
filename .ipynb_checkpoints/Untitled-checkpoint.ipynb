# %% [markdown]
# # Import library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Analysis

# %%
cobify = pd.read_csv("measurements_cleaned.csv")

# %%
cobify.head()
# Out:
#    distance  consume  speed  temp_inside  temp_outside gas_type  AC  rain  \
# 0      28.0      5.0     26         21.5            12      E10   0     0
# 1      12.0      4.2     30         21.5            13      E10   0     0
# 2      11.2      5.5     38         21.5            15      E10   0     0
# 3      12.9      3.9     36         21.5            14      E10   0     0
# 4      18.5      4.5     46         21.5            15      E10   0     0
#
#    sun  E10  SP98
# 0    0    1     0
# 1    0    1     0
# 2    0    1     0
# 3    0    1     0
# 4    0    1     0

# %%
# Matriz de correlación de ambos tipos de gasolina

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (10.,7.)})
sns.set_style("whitegrid")
corrMatrix = cobify.corr()
sns.heatmap(corrMatrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(cobify, hue="gas_type")

# %%
sns.histplot(x=cobify.distance)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='Count'>

# %%
sns.boxplot(x="distance", data=cobify)
# Out:
# <AxesSubplot:xlabel='distance'>

# %%
sns.histplot(x=cobify.consume);

# %%
sns.histplot(x=cobify.speed);
