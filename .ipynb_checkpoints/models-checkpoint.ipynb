# %%
import pandas as pd   
import numpy as np    
import matplotlib.pyplot as plt 
# %matplotlib inline
# %config InlineBackend.figure_formats = ['retina']
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df_train=pd.read_csv('../reto_data/inputs/measurements.csv')
df_train.head()
# Out:
#   distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0       28       5     26        21,5            12      NaN      E10   0
# 1       12     4,2     30        21,5            13      NaN      E10   0
# 2     11,2     5,5     38        21,5            15      NaN      E10   0
# 3     12,9     3,9     36        21,5            14      NaN      E10   0
# 4     18,5     4,5     46        21,5            15      NaN      E10   0
#
#    rain  sun refill liters refill gas
# 0     0    0            45        E10
# 1     0    0           NaN        NaN
# 2     0    0           NaN        NaN
# 3     0    0           NaN        NaN
# 4     0    0           NaN        NaN

# %%
df_train_2=pd.read_excel('../reto_data/inputs/measurements2.xlsx')
df_train_2.head()
# Out:
#    distance  consume  speed  temp_inside  temp_outside specials gas_type  AC  \
# 0      28.0      5.0     26         21.5            12      NaN      E10   0
# 1      12.0      4.2     30         21.5            13      NaN      E10   0
# 2      11.2      5.5     38         21.5            15      NaN      E10   0
# 3      12.9      3.9     36         21.5            14      NaN      E10   0
# 4      18.5      4.5     46         21.5            15      NaN      E10   0
#
#    rain  sun  refill liters refill gas
# 0     0    0           45.0        E10
# 1     0    0            NaN        NaN
# 2     0    0            NaN        NaN
# 3     0    0            NaN        NaN
# 4     0    0            NaN        NaN

# %% [markdown]
# ### First visualizations

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   distance       388 non-null    object
#  1   consume        388 non-null    object
#  2   speed          388 non-null    int64
#  3   temp_inside    376 non-null    object
#  4   temp_outside   388 non-null    int64
#  5   specials       93 non-null     object
#  6   gas_type       388 non-null    object
#  7   AC             388 non-null    int64
#  8   rain           388 non-null    int64
#  9   sun            388 non-null    int64
#  10  refill liters  13 non-null     object
#  11  refill gas     13 non-null     object
# dtypes: int64(5), object(7)
# memory usage: 36.5+ KB

# %%
df_train_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   distance       388 non-null    float64
#  1   consume        388 non-null    float64
#  2   speed          388 non-null    int64
#  3   temp_inside    376 non-null    float64
#  4   temp_outside   388 non-null    int64
#  5   specials       93 non-null     object
#  6   gas_type       388 non-null    object
#  7   AC             388 non-null    int64
#  8   rain           388 non-null    int64
#  9   sun            388 non-null    int64
#  10  refill liters  13 non-null     float64
#  11  refill gas     13 non-null     object
# dtypes: float64(4), int64(5), object(3)
# memory usage: 36.5+ KB

# %%
df_train.describe()
# Out:
#             speed  temp_outside          AC        rain         sun
# count  388.000000    388.000000  388.000000  388.000000  388.000000
# mean    41.927835     11.358247    0.077320    0.123711    0.082474
# std     13.598524      6.991542    0.267443    0.329677    0.275441
# min     14.000000     -5.000000    0.000000    0.000000    0.000000
# 25%     32.750000      7.000000    0.000000    0.000000    0.000000
# 50%     40.500000     10.000000    0.000000    0.000000    0.000000
# 75%     50.000000     16.000000    0.000000    0.000000    0.000000
# max     90.000000     31.000000    1.000000    1.000000    1.000000

# %%
df_train_2.describe()
# Out:
#          distance     consume       speed  temp_inside  temp_outside  \
# count  388.000000  388.000000  388.000000   376.000000    388.000000
# mean    19.652835    4.912371   41.927835    21.929521     11.358247
# std     22.667837    1.033172   13.598524     1.010455      6.991542
# min      1.300000    3.300000   14.000000    19.000000     -5.000000
# 25%     11.800000    4.300000   32.750000    21.500000      7.000000
# 50%     14.600000    4.700000   40.500000    22.000000     10.000000
# 75%     19.000000    5.300000   50.000000    22.500000     16.000000
# max    216.100000   12.200000   90.000000    25.500000     31.000000
#
#                AC        rain         sun  refill liters
# count  388.000000  388.000000  388.000000      13.000000
# mean     0.077320    0.123711    0.082474      37.115385
# std      0.267443    0.329677    0.275441       8.587282
# min      0.000000    0.000000    0.000000      10.000000
# 25%      0.000000    0.000000    0.000000      37.600000
# ...

# %%
## ambas tablas son iguales, ignoramos la 2

# %% [markdown]
# ### Pandas profiling for better visualization

# %%
import pandas_profiling
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df_train, title="Pandas Profiling Report", explorative=True)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.11.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-07-28 15:59:24.087791&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ### drop nan

# %%
df_train.isna().sum()
# Out:
# distance           0
# consume            0
# speed              0
# temp_inside       12
# temp_outside       0
# specials         295
# gas_type           0
# AC                 0
# rain               0
# sun                0
# refill liters    375
# refill gas       375
# dtype: int64

# %%
df_train=df_train.drop(['specials', 'refill liters', 'refill gas'], axis='columns')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   distance      388 non-null    object
#  1   consume       388 non-null    object
#  2   speed         388 non-null    int64
#  3   temp_inside   376 non-null    object
#  4   temp_outside  388 non-null    int64
#  5   gas_type      388 non-null    object
#  6   AC            388 non-null    int64
#  7   rain          388 non-null    int64
#  8   sun           388 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 27.4+ KB

# %% [markdown]
# ### Categorical and numerical columns

# %%
num_cols = list(df_train._get_numeric_data().columns)
print("Numerical columns: ", num_cols)

cat_cols=list(set(df_train.columns) - set(num_cols))
print("Categorical columns: ", cat_cols)
# Out:
# Numerical columns:  ['speed', 'temp_outside', 'AC', 'rain', 'sun']
# Categorical columns:  ['consume', 'distance', 'gas_type', 'temp_inside']

# %% [markdown]
# #### Explore categorical columns

# %%
for c in cat_cols:
    print(c, ">", set(df_train[c]))
    print("")
# Out:
# consume > {'5,8', '4', '10,8', '5,7', '4,1', '4,3', '3,6', '6,3', '3,8', '6,6', '6,2', '4,6', '12,2', '5,9', '6,4', '5,1', '7,1', '5,6', '8,1', '3,3', '4,7', '6', '3,7', '5,4', '5,2', '6,1', '11,5', '4,5', '5,3', '4,4', '3,9', '9,9', '6,9', '9', '7,9', '5,5', '8,7', '5', '4,9', '4,8', '7,4', '6,5', '4,2'}
#
# ...

# %%
df_train['temp_inside'] = pd.to_numeric(df_train['temp_inside'], errors='coerce')
df_train['consume'] = pd.to_numeric(df_train['consume'], errors='coerce')
df_train['distance'] = pd.to_numeric(df_train['distance'], errors='coerce')

# %%
num_cols = list(df_train._get_numeric_data().columns)
print("Numerical columns: ", num_cols)

cat_cols=list(set(df_train.columns) - set(num_cols))
print("Categorical columns: ", cat_cols)
# Out:
# Numerical columns:  ['distance', 'consume', 'speed', 'temp_inside', 'temp_outside', 'AC', 'rain', 'sun']
# Categorical columns:  ['gas_type']

# %%
df_train['gas_type'] = df_train['gas_type'].map({'SP98': 1, 'E10': 0})
set(df_train['gas_type'])
# Out:
# {0, 1}

# %% [markdown]
# #### gas_type

# %%
df_train.gas_type.value_counts().plot(kind='bar');

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   distance      52 non-null     float64
#  1   consume       49 non-null     float64
#  2   speed         388 non-null    int64
#  3   temp_inside   169 non-null    float64
#  4   temp_outside  388 non-null    int64
#  5   gas_type      388 non-null    int64
#  6   AC            388 non-null    int64
#  7   rain          388 non-null    int64
#  8   sun           388 non-null    int64
# dtypes: float64(3), int64(6)
# memory usage: 27.4 KB

# %% [markdown]
# ### Rellenamos los nan

# %%
temp_inside = df_train['temp_inside'].dropna()
temp_inside_avg = temp_inside.mean()
df_train['temp_inside'] = df_train['temp_inside'].fillna(temp_inside_avg)

# %%
distance = df_train['distance'].dropna()
distance_avg = distance.mean()
df_train['distance'] = df_train['distance'].fillna(distance_avg)

# %%
consume = df_train['consume'].dropna()
consume_avg = consume.mean()
df_train['consume'] = df_train['consume'].fillna(consume_avg)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   distance      388 non-null    float64
#  1   consume       388 non-null    float64
#  2   speed         388 non-null    int64
#  3   temp_inside   388 non-null    float64
#  4   temp_outside  388 non-null    int64
#  5   gas_type      388 non-null    int64
#  6   AC            388 non-null    int64
#  7   rain          388 non-null    int64
#  8   sun           388 non-null    int64
# dtypes: float64(3), int64(6)
# memory usage: 27.4 KB

# %% [markdown]
# ### Correlations map

# %%
sns.set(style="white")
# Generate a mask for the upper triangle
mask = np.zeros_like(df_train.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure to control size of heatmap
fig, ax = plt.subplots(figsize=(16,12))
# Create a custom color palette
cmap = sns.diverging_palette(255, 10, as_cmap=True)  # as_cmap returns a matplotlib colormap object rather than a list of colors
# Red=10, Green=128, Blue=255
# Plot the heatmap
sns.heatmap(df_train.corr(), mask=mask, annot=True, square=True, cmap=cmap , vmin=-1, vmax=1, ax=ax)  # annot display corr label
# Prevent Heatmap Cut-Off Issue
bottom, top = ax.get_ylim()
ax.set_ylim(bottom+0.5, top-0.5)
# Out:
# (9.5, -0.5)

# %%
df_train['distance'].plot.hist()
plt.show()

# %%
df_train['consume'].plot.hist()
plt.show()

# %%
df_train['speed'].plot.hist()
plt.show()

# %%
df_train['temp_inside'].plot.hist()
plt.show()

# %%
df_train['temp_outside'].plot.hist()
plt.show()

# %%
df_train['AC'].plot.hist()
plt.show()

# %% [markdown]
# ### Consumo fuel vs distancia recorrida:

# %%
df_train.describe()
# Out:
#          distance     consume       speed  temp_inside  temp_outside  \
# count  388.000000  388.000000  388.000000   388.000000    388.000000
# mean    19.596154    4.816327   41.927835    21.934911     11.358247
# std     10.112100    0.302218   13.598524     0.810595      6.991542
# min      2.000000    4.000000   14.000000    19.000000     -5.000000
# 25%     19.596154    4.816327   32.750000    21.934911      7.000000
# 50%     19.596154    4.816327   40.500000    21.934911     10.000000
# 75%     19.596154    4.816327   50.000000    22.000000     16.000000
# max    211.000000    9.000000   90.000000    25.000000     31.000000
#
#          gas_type          AC        rain         sun
# count  388.000000  388.000000  388.000000  388.000000
# mean     0.587629    0.077320    0.123711    0.082474
# std      0.492897    0.267443    0.329677    0.275441
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# ...

# %% [markdown]
# ### Media consumo por tipo de combustible

# %%
#La media de consumo es mayor en SP98 (SP98: 1, E10: 0)
df_train.groupby(['gas_type']).mean()
# Out:
#            distance   consume      speed  temp_inside  temp_outside        AC  \
# gas_type
# 0         18.992909  4.808036  43.506250    21.993713      10.11875  0.043750
# 1         20.019484  4.822145  40.820175    21.893647      12.22807  0.100877
#
#               rain       sun
# gas_type
# 0         0.100000  0.075000
# 1         0.140351  0.087719

# %% [markdown]
# ### Feature columns

# %%
df_train.columns
# Out:
# Index(['distance', 'consume', 'speed', 'temp_inside', 'temp_outside',
#        'gas_type', 'AC', 'rain', 'sun'],
#       dtype='object')

# %%
X = df_train[['distance', 'speed', 'temp_inside', 'temp_outside',
       'gas_type', 'AC', 'rain', 'sun']].values
y = df_train['consume'].values

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X = sc.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y, random_state=9, train_size = 0.8)

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
y_pred = lin_reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score  
print("MSE: {:.2f}".format(mean_squared_error(y_test, y_pred)))  
print("R2: {:.2f}".format(r2_score(y_test, y_pred)))
# Out:
# MSE: 0.02
# R2: -0.16

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
ridge = Ridge()

parameters = {"alpha":[1e-15, 1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20]}
ridge_regression = GridSearchCV(ridge, parameters, scoring='neg_mean_squared_error', cv=5)
ridge_regression.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regression.best_params_)
print(ridge_regression.best_score_)
# Out:
# {'alpha': 20}
# -0.10203979770942706

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()

parameters = {"alpha":[1e-15, 1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20]}
lasso_regression = GridSearchCV(lasso, parameters, scoring='neg_mean_squared_error', cv=5)
lasso_regression.fit(X, y)

print(lasso_regression.best_params_)
print(lasso_regression.best_score_)
# Out:
# {'alpha': 1}
# -0.09169261449914168

# %%
from xgboost import XGBRegressor

my_model = XGBRegressor()
my_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
from sklearn.metrics import mean_absolute_error

predictions = my_model.predict(x_test)
print("Mean Absolute Error: " + str(mean_absolute_error(predictions, y_test)))
# Out:
# Mean Absolute Error: 1.2585654077824344

# %% [markdown]
# ### Predicción con los distintos tipos de fuel

# %%
#SP98: 1, E10: 0 
SP98=df_train.loc[df_train['gas_type']==1]
E10=df_train.loc[df_train['gas_type']==0]

# %%
X_SP98 = SP98[['distance', 'speed', 'temp_inside', 'temp_outside',
       'gas_type', 'AC', 'rain', 'sun']].values
y_SP98 = SP98['consume'].values

# %%
X_E10 = E10[['distance', 'speed', 'temp_inside', 'temp_outside',
       'gas_type', 'AC', 'rain', 'sun']].values
y_E10 = E10['consume'].values

# %%
x_train_SP98,x_test_SP98,y_train_SP98,y_test_SP98 = train_test_split(X_SP98,y_SP98, random_state=9, train_size = 0.8)

# %%
x_train_E10,x_test_E10,y_train_E10,y_test_E10 = train_test_split(X_E10,y_E10, random_state=9, train_size = 0.8)

# %%
#SP98: 1, E10: 0
SP98_pred = lin_reg.predict(x_test_SP98)
E10_pred = lin_reg.predict(x_test_E10)

# %%
SP98_pred.mean()
# Out:
# 4.820667132753105

# %%
E10_pred.mean()
# Out:
# 4.819556547856802

# %% [markdown]
# ### xgboost

# %%
import xgboost as xgb
xgbr = xgb.XGBRegressor(objective='reg:squarederror')
xgbr.fit(x_train, y_train)
 
ypred = xgbr.predict(x_test)

print("MSE: {:.2f}".format(mean_squared_error(y_test, y_pred)))  
print("R2: {:.2f}".format(r2_score(y_test, y_pred)))
# Out:
# MSE: 0.02
# R2: -0.16

# %%
SP98_pred = xgbr.predict(x_test_SP98)
E10_pred = xgbr.predict(x_test_E10)

# %%
SP98_pred.mean()
# Out:
# 4.8216867

# %%
E10_pred.mean()
# Out:
# 4.7593746
